# %%
from urllib.parse import urlparse, parse_qs
u = urlparse('https://github.com/andrewbeattycourseware/wsaa-courseware')
u.netloc , u.path, parse_qs(u.query)

#print(f'The network location is {u.netloc}, the path is {u.path}, and the query parameters are {parse_qs(u.query)}')
# Out:
# ('github.com', '/andrewbeattycourseware/wsaa-courseware', {})

# %%
import requests
url1 = 'https://www.cso.ie/en/index.html'

response = requests.get(url1)
print(response.status_code)
# Out:
# 200

# %%
url2 = "https://jsonplaceholder.typicode.com/posts/1"

response2 = requests.delete(url2)
print(response2.status_code)
# Out:
# 200

# %%
url3 = "https://api.twitter.com/oauth/request_token"

response3 = requests.post(url3)
print(response3.status_code)
# Out:
# 400
