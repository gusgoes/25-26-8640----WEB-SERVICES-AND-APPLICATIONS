# %%
from config import apikey

print(apikey)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from config import apikey
#       3 print(apikey)
#
# ImportError: cannot import name 'apikey' from 'config' (c:\Users\gusgo\OneDrive\Higher Diploma in Science in Computing in Data Analytics\25-26-8640----WEB-SERVICES-AND-APPLICATIONS\lab\lab04\config.py)
